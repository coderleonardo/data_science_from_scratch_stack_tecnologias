# %% [markdown]
# # Regressão linear

# %%
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ## Leitura dos dados

# %%
X = np.array([0, 1, 2, 3])
y = np.array([0, 1, 2, 3])

# %% [markdown]
# ## Representando uma Reta

# %%
def predict(alpha, beta, X):
    return alpha * X + beta

# %%
alpha = 0.50 # Coeficiente angular da reta
beta = 0 # Coeficiente linear da reta 

y_hat = predict(alpha=alpha, beta=beta, X=X)

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(X,y, c='b')
plt.plot(X, y_hat, 'r')
plt.text(0,2.90,'Alpha={} e Beta={}'.format(alpha, beta), fontdict={'size': 15})
plt.show()

# %% [markdown]
# ## Escolhendo o melhor alpha e beta

# %%
tamanho = len(X)
X_b = np.c_[np.ones((tamanho, 1)), X]  # add x0 = 1 to each instance

X_b
# Out:
# array([[1., 0.],
#        [1., 1.],
#        [1., 2.],
#        [1., 3.]])

# %%
# Método dos mínimos quadrados
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
theta_best # (linear, inclinação)
# Out:
# array([4.4408921e-16, 1.0000000e+00])

# %%
alpha = theta_best[1] # Inclinação
beta = theta_best[0]

# %%
y_hat = predict(alpha=alpha, beta=beta, X=X)

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(X,y, c='b')
plt.plot(X, y_hat, 'r')
plt.text(0,2.90,'Alpha={} e Beta={}'.format(round(alpha,3), round(beta,3)), fontdict={'size': 15})
# Out:
# Text(0, 2.9, 'Alpha=1.0 e Beta=0.0')
